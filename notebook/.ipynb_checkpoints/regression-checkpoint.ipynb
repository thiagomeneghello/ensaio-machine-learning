# %% [markdown]
# # 0.0 Import Bibs

# %%
import pandas as pd
import numpy as np
from sklearn import neighbors as nb
from sklearn import linear_model as lm
from sklearn import metrics as mt
from sklearn import tree as tr
from sklearn import model_selection as ms
from imblearn.under_sampling import NearMiss
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from sklearn import cluster as ct
from sklearn import datasets as ds
from sklearn import ensemble as en
from sklearn import preprocessing as pp
from matplotlib import pyplot as plt
import cv2

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1.0 Load Datasets

# %%
x_train = pd.read_csv('../datasets/regression/X_training_reg.csv')
y_train = pd.read_csv('../datasets/regression/y_training_reg.csv')
x_val = pd.read_csv('../datasets/regression/X_validation_reg.csv')
y_val = pd.read_csv('../datasets/regression/y_val_reg.csv')
x_test = pd.read_csv('../datasets/regression/X_test_reg.csv')
y_test = pd.read_csv('../datasets/regression/y_test_reg.csv')

# %% [markdown]
# # 2.0 Defs

# %%
# metrics = R2, MSE, RMSE, MAE, MAPE
def r2_score(y_test, yhat):
    r2 = mt.r2_score(y_test, yhat)
    return r2

def mse(y_test, yhat):
    mse = mt.mean_squared_error(y_test, yhat)
    return mse

def rmse(y_test, yhat):
    rmse = np.sqrt(mt.mean_squared_error(y_test, yhat))
    return rmse

def mae(y_test, yhat):
    mae = mt.mean_absolute_error(y_test, yhat)
    return mae

def mape(y_test, yhat):
    mape = mt.mean_absolute_percentage_error(y_test, yhat)
    return mape

def metrics_list(lista_a, metrica_a, lista_b, metrica_b, lista_c, metrica_c, lista_d, metrica_d, lista_e, metrica_e):
    lista_a.append(metrica_a)
    lista_b.append(metrica_b)
    lista_c.append(metrica_c)
    lista_d.append(metrica_d)
    lista_e.append(metrica_e)
    return lista_a, lista_b, lista_c, lista_d, lista_e

def matrix(list, param_1, param_2):
    list_matrix = np.array(list).reshape(len(param_1), len(param_2))
    return list_matrix

def best_params(lista, param1, param2):
    indice = np.argmin(lista)
    linha, coluna = np.unravel_index(indice, lista.shape)
    p1_best = param1[linha] 
    p2_best = param2[coluna] 
    return print("Melhor número de parametro 1:{}".format(p1_best)), print(), print("Melhor número de parametro 2:{}".format(p2_best))

# %%
def tabela (algoritmo, parametro1, n, parametro2, n2, r2_train, r2_val, r2_test, mse_train, mse_val, mse_test,
            rmse_train, rmse_val, rmse_test, mae_train, mae_val, mae_test, mape_train, mape_val, mape_test):
    df = pd.DataFrame({algoritmo:['dataset train', 'dataset validation', 'dataset test'],
                       parametro1:[n, n, n],
                       parametro2: [n2, n2, n2],
                       'R2_Score': [r2_train, r2_val, r2_test],
                       'MSE': [mse_train, mse_val, mse_test],
                       'RMSE': [rmse_train, rmse_val, rmse_test],
                       'MAE': [mae_train, mae_val, mae_test],
                       'MAPE': [mape_train, mape_val, mape_test]})
    return df

# %% [markdown]
# # 3.0 Ensaio Machine Learnig

# %% [markdown]
# ### 1) Linear Regression

# %%
def linear_regression(x_train, y_train, x_test):
    model = lm.LinearRegression()
    model.fit(x_train, y_train)
    yhat = model.predict(x_test)
    return yhat

# %%
yhat_train = linear_regression(x_train, y_train, x_train)
yhat_val = linear_regression(x_train, y_train, x_val)
yhat_test = linear_regression(pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)

# %%
r2_train = r2_score(y_train, yhat_train)
r2_val = r2_score(y_val, yhat_val)
r2_test = r2_score(y_test, yhat_test)
mse_train = mse(y_train, yhat_train)
mse_val = mse(y_val, yhat_val)
mse_test = mse(y_test, yhat_test)
rmse_train = rmse(y_train, yhat_train)
rmse_val = rmse(y_val, yhat_val)
rmse_test = rmse(y_test, yhat_test)
mae_train = mae(y_train, yhat_train)
mae_val = mae(y_val, yhat_val)
mae_test = mae(y_test, yhat_test)
mape_train = mape(y_train, yhat_train)
mape_val = mape(y_val, yhat_val)
mape_test = mape(y_test, yhat_test)

# %%
df_linear_reg = tabela('Linear_Regression','-', '-', '-', '-', r2_train, r2_val, r2_test,
                       mse_train, mse_val, mse_test, rmse_train, rmse_val, rmse_test,
                       mae_train, mae_val, mae_test, mape_train, mape_val, mape_test)
df_linear_reg
# Out:
#     Linear_Regression  -  R2_Score         MSE       RMSE        MAE      MAPE
# 0       dataset train  -  0.046058  455.996112  21.354065  16.998249  8.653186
# 1  dataset validation  -  0.039925  458.447042  21.411376  17.039754  8.682542
# 2        dataset test  -  0.051166  461.988435  21.493916  17.144197  8.531355

# %% [markdown]
# ## 2) Decision Tree Regressor

# %%
def decision_tree_regressor(depth, x_train, y_train, x_test):
    model = tr.DecisionTreeRegressor(max_depth=depth, random_state=42)
    model.fit(x_train, y_train)
    ypred = model.predict(x_test)
    return ypred

# %% [markdown]
# ### dados de treino

# %%
depth = np.arange(10, 63, 3)
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(depth)):
    ypred_train = decision_tree_regressor(depth[i], x_train, y_train, x_train)
    r2_train = r2_score(y_train, ypred_train)
    mse_train = mse(y_train, ypred_train)
    rmse_train = rmse(y_train, ypred_train)
    mae_train = mae(y_train, ypred_train)
    mape_train = mape(y_train, ypred_train)
    r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                     mse_list, mse_train,
                                                                     rmse_list, rmse_train,
                                                                     mae_list, mae_train,
                                                                     mape_list, mape_train)

# %%
plt.plot(depth, r2_list,'r--', label = "R2_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(depth, mae_list,'g--', label = "MAE_Score")
plt.plot(depth, mape_list,'m--', label = "MAPE_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(depth, mse_list,'b--', label = "MSE_Score")
plt.plot(depth, rmse_list,'k--', label = "RMSE_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %% [markdown]
# ### dados de treino e validação

# %%
depth = np.arange(10, 63, 3)
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(depth)):
    ypred_val = decision_tree_regressor(depth[i], x_train, y_train, x_val)
    r2_val = r2_score(y_val, ypred_val)
    mse_val = mse(y_val, ypred_val)
    rmse_val = rmse(y_val, ypred_val)
    mae_val = mae(y_val, ypred_val)
    mape_val = mape(y_val, ypred_val)
    r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                     mse_list, mse_val,
                                                                     rmse_list, rmse_val,
                                                                     mae_list, mae_val,
                                                                     mape_list, mape_val)

# %%
plt.plot(depth, r2_list,'r--', label = "R2_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(depth, mse_list,'o-', label = "MSE_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(depth, rmse_list,'o--', label = "RMSE_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(depth, mae_list,'g--', label = "MAE_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(depth, mape_list,'m--', label = "MAPE_Score")
plt.xlabel("N_Depth")
plt.ylabel("Metrics")
plt.legend()

# %%
d_best = r2_list.index(min(r2_list))
depth[d_best]
# Out:
# 28

# %% [markdown]
# ### dados treino, validação e teste

# %%
depth=28
ypred_test = decision_tree_regressor(depth, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)

# %%
r2_test = r2_score(y_test, ypred_test)
mse_test = mse(y_test, ypred_test)
rmse_test = rmse(y_test, ypred_test)
mae_test = mae(y_test, ypred_test)
mape_test = mape(y_test, ypred_test)

# %% [markdown]
# ### tabela final

# %%
depth=28
ypred_train = decision_tree_regressor(depth, x_train, y_train, x_train)
r2_train = r2_score(y_train, ypred_train)
mse_train = mse(y_train, ypred_train)
rmse_train = rmse(y_train, ypred_train)
mae_train = mae(y_train, ypred_train)
mape_train = mape(y_train, ypred_train)

# %%
depth=28
ypred_val = decision_tree_regressor(depth, x_train, y_train, x_val)
r2_val = r2_score(y_val, ypred_val)
mse_val = mse(y_val, ypred_val)
rmse_val = rmse(y_val, ypred_val)
mae_val = mae(y_val, ypred_val)
mape_val = mape(y_val, ypred_val)

# %%
df_dtr = tabela("Decision_Tree_Regressor", '-','-','max_depth', 28, r2_train, r2_val, r2_test,
                mse_train, mse_val, mse_test, rmse_train, rmse_val, rmse_test, mae_train, mae_val, mae_test,
                mape_train, mape_val, mape_test)

df_dtr
# Out:
#   Decision_Tree_Regressor  -  max_depth  R2_Score         MSE       RMSE  \
# 0           dataset train  -         28  0.990791    4.402052   2.098107
# 1      dataset validation  -         28 -0.309388  625.248181  25.004963
# 2            dataset test  -         28 -0.170129  569.737119  23.869167
#
#          MAE      MAPE
# 0   0.286160  0.084054
# 1  17.262808  6.878538
# 2  15.790974  5.989356

# %% [markdown]
# ## 3) Random Forest Regressor

# %%
def random_forest_regressor(estimators, depth, x_train, y_train, x_test):
    model = en.RandomForestRegressor(n_estimators = estimators, max_depth = depth,
                                     n_jobs = -1, random_state=42)
    model.fit(x_train, y_train)
    ypred = model.predict(x_test)
    return ypred

# %% [markdown]
# ### dados de treino

# %%
estimators = np.arange(91, 153, 2)
depth = np.arange(5, 100, 7)
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
for i in range(len(estimators)):
    for j in range(len(depth)):
        ypred_train = random_forest_regressor(estimators[i], depth[j], x_train, y_train, x_train)
        r2_train = r2_score(y_train, ypred_train)
        mse_train = mse(y_train, ypred_train)
        rmse_train = rmse(y_train, ypred_train)
        mae_train = mae(y_train, ypred_train)
        mape_train = mape(y_train, ypred_train)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                         mse_list, mse_train,
                                                                         rmse_list, rmse_train,
                                                                         mae_list, mae_train,
                                                                         mape_list, mape_train)

# %%
r2_mx= matrix(r2_list, estimators, depth)
mse_mx=matrix(mse_list, estimators, depth)
rmse_mx=matrix(rmse_list, estimators, depth)
mae_mx=matrix(mae_list, estimators, depth)
mape_mx=matrix(mape_list, estimators, depth)

# %%
for j in range(len(depth)):
    plt.plot(estimators, r2_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('R2_Score em dados de treino')
plt.title('R2_Score em dados de treino em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, mse_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('MSE em dados de treino')
plt.title('MSE em dados de treino em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, rmse_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('RMSE em dados de treino')
plt.title('RMSE em dados de treino em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, mae_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('MAE em dados de treino')
plt.title('MAE em dados de treino em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, mape_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('MAPE em dados de treino')
plt.title('MAPE em dados de treino em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %% [markdown]
# ### dados de treino e validação

# %%
estimators = np.arange(91, 153, 2)
depth = np.arange(5, 100, 7)
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
for i in range(len(estimators)):
    for j in range(len(depth)):
        ypred_val = random_forest_regressor(estimators[i], depth[j], x_train, y_train, x_val)
        r2_val = r2_score(y_val, ypred_val)
        mse_val = mse(y_val, ypred_val)
        rmse_val = rmse(y_val, ypred_val)
        mae_val = mae(y_val, ypred_val)
        mape_val = mape(y_val, ypred_val)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                         mse_list, mse_val,
                                                                         rmse_list, rmse_val,
                                                                         mae_list, mae_val,
                                                                         mape_list, mape_val)

# %%
r2_mx = matrix(r2_list, estimators, depth)
mse_mx = matrix(mse_list, estimators, depth)
rmse_mx = matrix(rmse_list, estimators, depth)
mae_mx = matrix(mae_list, estimators, depth) 
mape_mx = matrix(mape_list, estimators, depth)

# %%
#definir melhores parâmetros estimators e depth
indice = np.argmin(rmse_mx)
linha, coluna = np.unravel_index(indice, rmse_mx.shape)
est_best = estimators[linha] #151
depth_best = depth[coluna] #33
print("Melhor número de estimators:{}".format(est_best))
print()
print("Melhor número de depth:{}".format(depth_best))
# Out:
# Melhor número de estimators:151
#
# Melhor número de depth:33

# %%
for j in range(len(depth)):
    plt.plot(estimators, r2_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('R2_Score em dados de validação')
plt.title('R2_Score em dados de validação em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, mse_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('MSE em dados de validação')
plt.title('MSE em dados de validação em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, rmse_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('RMSE em dados de validação')
plt.title('RMSE em dados de validação em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, mae_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('MAE em dados de validação')
plt.title('MAE em dados de validação em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %%
for j in range(len(depth)):
    plt.plot(estimators, mape_mx[:,j], label=f'Max_Depth={depth[j]}', marker='o')
plt.xlabel('N_Estimators')
plt.ylabel('MAPE em dados de validação')
plt.title('MAPE em dados de validação em função de n_estimators (para diferentes valores máximos de iteração)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.figure(figsize=(20, 20))

# %% [markdown]
# ### dados de treino, validação, teste

# %%
estimators = 151
depth = 33
ypred_test = random_forest_regressor(estimators, depth, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)
r2_test = r2_score(y_test, ypred_test)
mse_test = mse(y_test, ypred_test)
rmse_test = rmse(y_test, ypred_test)
mae_test = mae(y_test, ypred_test)
mape_test = mape(y_test, ypred_test)

# %% [markdown]
# ### tabela final

# %%
estimators = 151
depth = 33
ypred_train = random_forest_regressor(estimators, depth, x_train, y_train, x_train)
r2_train = r2_score(y_train, ypred_train)
mse_train = mse(y_train, ypred_train)
rmse_train = rmse(y_train, ypred_train)
mae_train = mae(y_train, ypred_train)
mape_train = mape(y_train, ypred_train)

# %%
estimators = 151
depth = 33
ypred_val = random_forest_regressor(estimators, depth, x_train, y_train, x_val)
r2_val = r2_score(y_val, ypred_val)
mse_val = mse(y_val, ypred_val)
rmse_val = rmse(y_val, ypred_val)
mae_val = mae(y_val, ypred_val)
mape_val = mape(y_val, ypred_val)

# %%
df_rfr = tabela('Random_Forest_Regressor', 'n_estimators', 151, 'max_depth', 33, r2_train, r2_val, r2_test,
                mse_train, mse_val, mse_test, rmse_train, rmse_val, rmse_test, mae_train, mae_val, mae_test,
                mape_train, mape_val, mape_test)

df_rfr
# Out:
#   Random_Forest_Regressor  n_estimators  max_depth  R2_Score         MSE  \
# 0           dataset train           151         33  0.903883   45.945244
# 1      dataset validation           151         33  0.336722  316.722823
# 2            dataset test           151         33  0.404679  289.862547
#
#         RMSE        MAE      MAPE
# 0   6.778292   4.849746  2.569131
# 1  17.796708  12.981367  7.027215
# 2  17.025350  12.224821  6.247119

# %% [markdown]
# ## 4) Polynomial Regression

# %%
def polynomial_regression(d, x_train, y_train, x_test):
    poly = pp.PolynomialFeatures(degree=d)
    xtrain_poly = poly.fit_transform(x_train)
    xtest_poly = poly.fit_transform(x_test)
    model = lm.LinearRegression()
    model.fit(xtrain_poly, y_train)
    yhat_pred = model.predict(xtest_poly)
    return yhat_pred

# %% [markdown]
# ### dados de treino

# %%
d = np.arange(1, 6, 1)
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(d)):
    ypred_train = polynomial_regression(d[i], x_train, y_train, x_train)
    preds.append(ypred_train)
    r2_train = r2_score(y_train, ypred_train)
    mse_train = mse(y_train, ypred_train)
    rmse_train = rmse(y_train, ypred_train)
    mae_train = mae(y_train, ypred_train)
    mape_train = mape(y_train, ypred_train)
    r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                     mse_list, mse_train,
                                                                     rmse_list, rmse_train,
                                                                     mae_list, mae_train,
                                                                     mape_list, mape_train)

# %%
plt.plot(d, r2_list,'r--', label = "R2_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(d, mae_list,'g--', label = "MAE_Score")
plt.plot(d, mape_list,'m--', label = "MAPE_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(d, mse_list,'b--', label = "MSE_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %%
plt.plot(d, rmse_list,'k--', label = "RMSE_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %% [markdown]
# ### dados treino e validação

# %%
d = np.arange(1, 6, 1)
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(d)):
    ypred_val = polynomial_regression(d[i], x_train, y_train, x_val)
    preds.append(ypred_train)
    r2_val = r2_score(y_val, ypred_val)
    mse_val = mse(y_val, ypred_val)
    rmse_val = rmse(y_val, ypred_val)
    mae_val = mae(y_val, ypred_val)
    mape_val = mape(y_val, ypred_val)
    r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                     mse_list, mse_val,
                                                                     rmse_list, rmse_val,
                                                                     mae_list, mae_val,
                                                                     mape_list, mape_val)

# %%
plt.plot(d, r2_list,'r--', label = "R2_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %%
best_d3 = r2_list.index(min(r2_list))
choice_degree3 = d[best_d3]
choice_degree3
# Out:
# 5

# %%
plt.plot(d, mse_list,'b--', label = "MSE_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %%
best_d = mse_list.index(min(mse_list))
choice_degree = d[best_d]
choice_degree
# Out:
# 2

# %%
plt.plot(d, rmse_list,'k--', label = "RMSE_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %%
best_d2 = rmse_list.index(min(rmse_list))
choice_degree2 = d[best_d2]
choice_degree2
# Out:
# 2

# %%
plt.plot(d, mae_list,'g--', label = "MAE_Score")
plt.plot(d, mape_list,'m--', label = "MAPE_Score")
plt.xlabel("N_Degree")
plt.ylabel("Metrics")
plt.legend()

# %% [markdown]
# ### dados treino, validação e teste

# %%
d=2
ypred_test = polynomial_regression(d, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)
r2_test = r2_score(y_test, ypred_test)
mse_test = mse(y_test, ypred_test)
rmse_test = rmse(y_test, ypred_test)
mae_test = mae(y_test, ypred_test)
mape_test = mape(y_test, ypred_test)

# %% [markdown]
# ### tabela final

# %%
d=2
ypred_train = polynomial_regression(d, x_train, y_train, x_train)
r2_train = r2_score(y_train, ypred_train)
mse_train = mse(y_train, ypred_train)
rmse_train = rmse(y_train, ypred_train)
mae_train = mae(y_train, ypred_train)
mape_train = mape(y_train, ypred_train)

# %%
d=2
ypred_val = polynomial_regression(d, x_train, y_train, x_val)
r2_val = r2_score(y_val, ypred_val)
mse_val = mse(y_val, ypred_val)
rmse_val = rmse(y_val, ypred_val)
mae_val = mae(y_val, ypred_val)
mape_val = mape(y_val, ypred_val)

# %%
df_pr = tabela("Polynomial_Regression",'-','-','degree',2, r2_train, r2_val, r2_test, mse_train, mse_val, mse_test,
               rmse_train, rmse_val, rmse_test, mae_train, mae_val, mae_test, mape_train, mape_val, mape_test)

df_pr
# Out:
#   Polynomial_Regression  -  degree  R2_Score         MSE       RMSE  \
# 0         dataset train  -       2  0.094195  432.986210  20.808321
# 1    dataset validation  -       2  0.066477  445.768223  21.113224
# 2          dataset test  -       2  0.090901  442.641386  21.039044
#
#          MAE      MAPE
# 0  16.458032  8.350540
# 1  16.749939  8.547931
# 2  16.736414  8.276972

# %% [markdown]
# ### 5) Regularização Linear Regression
#      a) Lasso
#      b) Ridge
#      c) Elastic Net

# %%
def lasso(a, max_it, x_train, y_train, x_test):
    lasso = lm.Lasso(alpha=a, max_iter=max_it, random_state=42)
    lasso.fit(x_train, y_train)
    yhat_lasso = lasso.predict(x_test)
    return yhat_lasso

def ridge(a, max_it, x_train, y_train, x_test):
    ridge = lm.Ridge(alpha=a, max_iter=max_it, random_state=42)
    ridge.fit(x_train,y_train)
    yhat_ridge = ridge.predict(x_test)
    return yhat_ridge

def elastic_net(a, ratio, max_it, x_train, y_train, x_test):
    elastic = lm.ElasticNet(alpha=a, l1_ratio=ratio, max_iter=max_it, random_state=42)
    elastic.fit(x_train,y_train)
    yhat_elastic = elastic.predict(x_test)
    return yhat_elastic

# %% [markdown]
# #### a) Lasso

# %% [markdown]
# ##### dados treino

# %%
a = np.arange(1, 301, 30)
max_it = np.arange(10, 1101, 70)

r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(a)):
    for j in range(len(max_it)):
        yhat_train_lasso = lasso(a[i], max_it[j], x_train, y_train, x_train)
        r2_train = r2_score(y_train, yhat_train_lasso)
        mse_train = mse(y_train, yhat_train_lasso)
        rmse_train = rmse(y_train, yhat_train_lasso)
        mae_train = mae(y_train, yhat_train_lasso)
        mape_train = mape(y_train, yhat_train_lasso)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                         mse_list, mse_train,
                                                                         rmse_list, rmse_train,
                                                                         mae_list, mae_train,
                                                                         mape_list, mape_train)

# %% [markdown]
# ##### dados treino e validação

# %%
a = np.arange(1, 301, 30)
max_it = np.arange(10, 1101, 70)

r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(a)):
    for j in range(len(max_it)):
        yhat_val_lasso = lasso(a[i], max_it[j], x_train, y_train, x_val)
        r2_val = r2_score(y_val, yhat_val_lasso)
        mse_val = mse(y_val, yhat_val_lasso)
        rmse_val = rmse(y_val, yhat_val_lasso)
        mae_val = mae(y_val, yhat_val_lasso)
        mape_val = mape(y_val, yhat_val_lasso)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                         mse_list, mse_val,
                                                                         rmse_list, rmse_val,
                                                                         mae_list, mae_val,
                                                                         mape_list, mape_val)

# %%
r2_list_mx = matrix(r2_list, a, max_it)

# %%
def best_params(lista, param1, param2):
    indice = np.argmin(lista)
    linha, coluna = np.unravel_index(indice, lista.shape)
    p1_best = param1[linha] #119
    p2_best = param2[coluna] #35
    return print("Melhor número de parametro 1:{}".format(p1_best)), print(), print("Melhor número de parametro 2:{}".format(p2_best))

# %%
teste = best_params(mse_list_mx, a, max_it)
# Out:
# Melhor número de parametro 1:1
#
# Melhor número de parametro 2:10

# %% [markdown]
# ##### dados treino, validação, teste

# %%
a = 1
max_it = 10

yhat_test_lasso = lasso(a, max_it, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)
r2_test = r2_score(y_test, yhat_test_lasso)
mse_test = mse(y_test, yhat_test_lasso)
rmse_test = rmse(y_test, yhat_test_lasso)
mae_test = mae(y_test, yhat_test_lasso)
mape_test = mape(y_test, yhat_test_lasso)

# %%
mse_test
# Out:
# 483.09641118147954

# %%
mse_val
# Out:
# 473.7470809154487

# %%
mse_train
# Out:
# 474.47483414340275

# %%
a = 1
max_it = 10

yhat_train_lasso = lasso(a, max_it, x_train, y_train, x_train)
r2_train = r2_score(y_train, yhat_train_lasso)
mse_train = mse(y_train, yhat_train_lasso)
rmse_train = rmse(y_train, yhat_train_lasso)
mae_train = mae(y_train, yhat_train_lasso)
mape_train = mape(y_train, yhat_train_lasso)

# %%
a = 1
max_it = 10

yhat_val_lasso = lasso(a, max_it, x_train, y_train, x_val)
r2_val = r2_score(y_val, yhat_val_lasso)
mse_val = mse(y_val, yhat_val_lasso)
rmse_val = rmse(y_val, yhat_val_lasso)
mae_val = mae(y_val, yhat_val_lasso)
mape_val = mape(y_val, yhat_val_lasso)

# %% [markdown]
# #### B) Ridge

# %% [markdown]
# ##### dados treino

# %%
a = np.arange(1, 301, 30)
max_it = np.arange(10, 1101, 70)

r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(a)):
    for j in range(len(max_it)):
        yhat_train_ridge = ridge(a[i], max_it[j], x_train, y_train, x_train)
        r2_train = r2_score(y_train, yhat_train_ridge)
        mse_train = mse(y_train, yhat_train_ridge)
        rmse_train = rmse(y_train, yhat_train_ridge)
        mae_train = mae(y_train, yhat_train_ridge)
        mape_train = mape(y_train, yhat_train_ridge)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                         mse_list, mse_train,
                                                                         rmse_list, rmse_train,
                                                                         mae_list, mae_train,
                                                                         mape_list, mape_train)

# %% [markdown]
# ##### dados treino e validação

# %%
a = np.arange(1, 301, 30)
max_it = np.arange(10, 1101, 70)

r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(a)):
    for j in range(len(max_it)):
        yhat_val_ridge = ridge(a[i], max_it[j], x_train, y_train, x_val)
        r2_val = r2_score(y_val, yhat_val_ridge)
        mse_val = mse(y_val, yhat_val_ridge)
        rmse_val = rmse(y_val,yhat_val_ridge)
        mae_val = mae(y_val, yhat_val_ridge)
        mape_val = mape(y_val, yhat_val_ridge)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                         mse_list, mse_val,
                                                                         rmse_list, rmse_val,
                                                                         mae_list, mae_val,
                                                                         mape_list, mape_val)

# %%
mse_list_mx = matrix(mse_list, a, max_it)

# %%
rmse_list_mx = matrix(rmse_list, a, max_it)

# %%
parametros = best_params(rmse_list_mx, a, max_it)
# Out:
# Melhor número de parametro 1:1
#
# Melhor número de parametro 2:10

# %% [markdown]
# ##### dados treino teste validação

# %%
a = 1
max_it = 10

yhat_test_ridge = ridge(a, max_it, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)
r2_test = r2_score(y_test, yhat_test_ridge)
mse_test = mse(y_test, yhat_test_ridge)
rmse_test = rmse(y_test, yhat_test_ridge)
mae_test = mae(y_test, yhat_test_ridge)
mape_test = mape(y_test, yhat_test_ridge)

# %%
a = 1
max_it = 10

yhat_val_ridge = ridge(a, max_it, x_train, y_train, x_val)
r2_val = r2_score(y_val, yhat_val_ridge)
mse_val = mse(y_val, yhat_val_ridge)
rmse_val = rmse(y_val, yhat_val_ridge)
mae_val = mae(y_val, yhat_val_ridge)
mape_val = mape(y_val, yhat_val_ridge)

# %%
a = 1
max_it = 10

yhat_train_ridge = ridge(a, max_it, x_train, y_train, x_train)
r2_train = r2_score(y_train, yhat_train_ridge)
mse_train = mse(y_train, yhat_train_ridge)
rmse_train = rmse(y_train, yhat_train_ridge)
mae_train = mae(y_train, yhat_train_ridge)
mape_train = mape(y_train, yhat_train_ridge)

# %% [markdown]
# #### C) Elastic Net

# %% [markdown]
# ##### dados de treino

# %%
a = np.arange(1, 301, 30)
max_it = np.arange(10, 1101, 70)
r = 0.5
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(a)):
    for j in range(len(max_it)):
        yhat_train_elastic = elastic_net(a[i], r, max_it[j], x_train, y_train, x_train)
        r2_train = r2_score(y_train, yhat_train_elastic)
        mse_train = mse(y_train, yhat_train_elastic)
        rmse_train = rmse(y_train, yhat_train_elastic)
        mae_train = mae(y_train, yhat_train_elastic)
        mape_train = mape(y_train, yhat_train_elastic)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                         mse_list, mse_train,
                                                                         rmse_list, rmse_train,
                                                                         mae_list, mae_train,
                                                                         mape_list, mape_train)

# %%
mse_list
# Out:
# [474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  474.2688893586024,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
#  478.012559979818,
# ...

# %% [markdown]
# ##### dados treino e validação

# %%
a = np.arange(1, 301, 30)
max_it = np.arange(10, 1101, 70)
r = 0.5
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(a)):
    for j in range(len(max_it)):
        yhat_val_elastic = elastic_net(a[i], r, max_it[j], x_train, y_train, x_val)
        r2_val = r2_score(y_val, yhat_val_elastic)
        mse_val = mse(y_val, yhat_val_elastic)
        rmse_val = rmse(y_val, yhat_val_elastic)
        mae_val = mae(y_val, yhat_val_elastic)
        mape_val = mape(y_val, yhat_val_elastic)
        r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                         mse_list, mse_val,
                                                                         rmse_list, rmse_val,
                                                                         mae_list, mae_val,
                                                                         mape_list, mape_val)

# %%
mse_list
# Out:
# [473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  473.6356162915494,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
#  477.5119556252973,
# ...

# %%
rmse_list
# Out:
# [21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.76317109916543,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
#  21.85204694359998,
# ...

# %%
mae_list
# Out:
# [17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.26290253848956,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
#  17.352835945449478,
# ...

# %%
mape_list
# Out:
# [8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.694035085887595,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
#  8.678722362628074,
# ...

# %%
r2_list
# Out:
# [0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  0.00811707101546788,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
#  -7.197077047660372e-07,
# ...

# %%
mse_list_mx = matrix(mse_list, a, max_it)
params = best_params(mse_list_mx, a, max_it)
# Out:
# Melhor número de parametro 1:1
#
# Melhor número de parametro 2:10

# %%
a = 1
max_it = 10
r = [0.1, 0.5, 0.9]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]

for i in range(len(r)):
    yhat_val_elastic = elastic_net(a, r[i], max_it, x_train, y_train, x_val)
    r2_val = r2_score(y_val, yhat_val_elastic)
    mse_val = mse(y_val, yhat_val_elastic)
    rmse_val = rmse(y_val, yhat_val_elastic)
    mae_val = mae(y_val, yhat_val_elastic)
    mape_val = mape(y_val, yhat_val_elastic)
    r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                     mse_list, mse_val,
                                                                     rmse_list, rmse_val,
                                                                     mae_list, mae_val,
                                                                     mape_list, mape_val)

# %%
 r2_list
# Out:
# [0.01011312084871685, 0.00811707101546788, 0.00782799261415923]

# %%
mape_list
# Out:
# [8.68708077294545, 8.694035085887595, 8.695622583546175]

# %% [markdown]
# ##### dados treino, validação e teste

# %%
a = 1
max_it = 10
r = 0.1
yhat_test_elastic = elastic_net(a, r, max_it, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test)
r2_test = r2_score(y_test, yhat_test_elastic)
mse_test = mse(y_test, yhat_test_elastic)
rmse_test = rmse(y_test, yhat_test_elastic)
mae_test = mae(y_test, yhat_test_elastic)
mape_test = mape(y_test, yhat_test_elastic)

# %%
a = 1
max_it = 10
r = 0.1
yhat_val_elastic = elastic_net(a, r, max_it, x_train, y_train, x_val)
r2_val = r2_score(y_val, yhat_val_elastic)
mse_val = mse(y_val, yhat_val_elastic)
rmse_val = rmse(y_val, yhat_val_elastic)
mae_val = mae(y_val, yhat_val_elastic)
mape_val = mape(y_val, yhat_val_elastic)

# %%
a = 1
max_it = 10
r = 0.1
yhat_train_elastic = elastic_net(a, r, max_it, x_train, y_train, x_train)
r2_train = r2_score(y_train, yhat_train_elastic)
mse_train = mse(y_train, yhat_train_elastic)
rmse_train = rmse(y_train, yhat_train_elastic)
mae_train = mae(y_train, yhat_train_elastic)
mape_train = mape(y_train, yhat_train_elastic)

# %% [markdown]
# #### Tabela Final das Regularizações

# %%
# como montar as tabelas

# %% [markdown]
# ### 6) Regularização Regressão Polinomial
#      a) Lasso
#      b) Ridge
#      c) Elastic Net

# %% [markdown]
# #### a) Lasso

# %%
def lasso_polynomial_regression(d, x_train, y_train, x_test, a, max_it):
    poly = pp.PolynomialFeatures(degree=d)
    xtrain_poly = poly.fit_transform(x_train)
    xtest_poly = poly.fit_transform(x_test)
    lasso = lm.Lasso(alpha=a, max_iter=max_it, random_state=42)
    lasso.fit(xtrain_poly, y_train)
    yhat_lasso = lasso.predict(xtest_poly)
    return yhat_lasso

# %% [markdown]
# ##### dados de treino

# %%
d = np.arange(1, 5, 1)
a = np.arange(1, 171, 15)
max_it = np.arange(5, 221, 35)
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
rmse_min = 100000
best_d = None
best_a = None
best_max_it = None

for i in range(len(d)):
    for j in range(len(a)):
        for k in range(len(max_it)):
            yhatlasso_train = lasso_polynomial_regression(d[i], x_train, y_train, x_train, a[j], max_it[k])
            r2_train = r2_score(y_train, yhatlasso_train)
            mse_train = mse(y_train, yhatlasso_train)
            rmse_train = rmse(y_train, yhatlasso_train)
            mae_train = mae(y_train, yhatlasso_train)
            mape_train = mape(y_train, yhatlasso_train)
            r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                             mse_list, mse_train,
                                                                             rmse_list, rmse_train,
                                                                             mae_list, mae_train,
                                                                             mape_list, mape_train)
            if rmse_val < rmse_min:
                rmse_min = rmse_val
                best_d = d[i]
                best_a = a[j]
                best_max_it = max_it[k]

# %%
best_dtrain = best_d
best_dtrain
# Out:
# 1

# %%
best_atrain = best_a
best_atrain
# Out:
# 1

# %%
best_max_ittrain = best_max_it
best_max_ittrain
# Out:
# 5

# %% [markdown]
# ##### dados treino e validação

# %%
d = np.arange(1, 5, 1)
a = np.arange(1, 171, 15)
max_it = np.arange(5, 221, 35)
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
rmse_min = 100000
best_d = None
best_a = None
best_max_it = None

for i in range(len(d)):
    for j in range(len(a)):
        for k in range(len(max_it)):
            yhatlasso_val = lasso_polynomial_regression(d[i], x_train, y_train, x_val, a[j], max_it[k])
            r2_val = r2_score(y_val, yhatlasso_val)
            mse_val = mse(y_val, yhatlasso_val)
            rmse_val = rmse(y_val, yhatlasso_val)
            mae_val = mae(y_val, yhatlasso_val)
            mape_val = mape(y_val, yhatlasso_val)
            r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                             mse_list, mse_val,
                                                                             rmse_list, rmse_val,
                                                                             mae_list, mae_val,
                                                                             mape_list, mape_val)
            if rmse_val < rmse_min:
                rmse_min = rmse_val
                best_d_val = d[i]
                best_a_val = a[j]
                best_max_it_val = max_it[k]

print(best_d_val)
print()
print(best_a_val)
print()
print(best_max_it_val)
# Out:
# 4
#
# 1
#
# 5

# %% [markdown]
# ##### dados treino, validação e teste

# %%
d = 4
a = 1
max_it = 5
yhatlasso_train = lasso_polynomial_regression(d, x_train, y_train, x_train, a, max_it)
r2_train = r2_score(y_train, yhatlasso_train)
mse_train = mse(y_train, yhatlasso_train)
rmse_train = rmse(y_train, yhatlasso_train)
mae_train = mae(y_train, yhatlasso_train)
mape_train = mape(y_train, yhatlasso_train)

# %%
d = 4
a = 1
max_it = 5
yhatlasso_val = lasso_polynomial_regression(d, x_train, y_train, x_val, a, max_it)
r2_val = r2_score(y_val, yhatlasso_val)
mse_val = mse(y_val, yhatlasso_val)
rmse_val = rmse(y_val, yhatlasso_val)
mae_val = mae(y_val, yhatlasso_val)
mape_val = mape(y_val, yhatlasso_val)

# %%
d = 4
a = 1
max_it = 5
yhatlasso_test = lasso_polynomial_regression(d, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test, a, max_it)
r2_test = r2_score(y_test, yhatlasso_test)
mse_test = mse(y_test, yhatlasso_test)
rmse_test = rmse(y_test, yhatlasso_test)
mae_test = mae(y_test, yhatlasso_test)
mape_test = mape(y_test, yhatlasso_test)

# %%
# fazer tabela

# %% [markdown]
# #### b) Ridge

# %%
def ridge_polynomial_regression(d, x_train, y_train, x_test, a, max_it):
    poly = pp.PolynomialFeatures(degree=d)
    xtrain_poly = poly.fit_transform(x_train)
    xtest_poly = poly.fit_transform(x_test)
    lasso = lm.Ridge(alpha=a, max_iter=max_it, random_state=42)
    lasso.fit(xtrain_poly, y_train)
    yhat_ridge = lasso.predict(xtest_poly)
    return yhat_ridge

# %% [markdown]
# ##### dados treino

# %%
d = np.arange(1, 5, 1)
a = np.arange(1, 171, 15)
max_it = np.arange(5, 221, 35)
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
rmse_min = 100000
best_d = None
best_a = None
best_max_it = None

for i in range(len(d)):
    for j in range(len(a)):
        for k in range(len(max_it)):
            yhatridge_train = ridge_polynomial_regression(d[i], x_train, y_train, x_train, a[j], max_it[k])
            r2_train = r2_score(y_train,  yhatridge_train)
            mse_train = mse(y_train,  yhatridge_train)
            rmse_train = rmse(y_train,  yhatridge_train)
            mae_train = mae(y_train,  yhatridge_train)
            mape_train = mape(y_train,  yhatridge_train)
            r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                             mse_list, mse_train,
                                                                             rmse_list, rmse_train,
                                                                             mae_list, mae_train,
                                                                             mape_list, mape_train)
            if rmse_train < rmse_min:
                rmse_min = rmse_val
                best_d_train = d[i]
                best_a_train = a[j]
                best_max_it_train = max_it[k]

print(best_d_train)
print()
print(best_a_train)
print()
print(best_max_it_train)
# Out:
# 4
#
# 166
#
# 215

# %% [markdown]
# ##### dados treino e validação

# %%
d = np.arange(1, 5, 1)
a = np.arange(1, 171, 15)
max_it = np.arange(5, 221, 35)
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
rmse_min = 100000
best_d = None
best_a = None
best_max_it = None

for i in range(len(d)):
    for j in range(len(a)):
        for k in range(len(max_it)):
            yhatridge_val = ridge_polynomial_regression(d[i], x_train, y_train, x_val, a[j], max_it[k])
            r2_val = r2_score(y_val,  yhatridge_val)
            mse_val = mse(y_val,  yhatridge_val)
            rmse_val = rmse(y_val,  yhatridge_val)
            mae_val = mae(y_val,  yhatridge_val)
            mape_val = mape(y_val,  yhatridge_val)
            r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                             mse_list, mse_val,
                                                                             rmse_list, rmse_val,
                                                                             mae_list, mae_val,
                                                                             mape_list, mape_val)
            if rmse_train < rmse_min:
                rmse_min = rmse_val
                best_d_val = d[i]
                best_a_val = a[j]
                best_max_it_val = max_it[k]

print(best_d_val)
print()
print(best_a_val)
print()
print(best_max_it_val)
# Out:
# 4
#
# 166
#
# 215

# %% [markdown]
# ##### dados treino, validação e test

# %%
d = 4
a = 166
max_it = 215

yhatridge_train = ridge_polynomial_regression(d, x_train, y_train, x_train, a, max_it)
r2_train = r2_score(y_train,  yhatridge_train)
mse_train = mse(y_train,  yhatridge_train)
rmse_train = rmse(y_train,  yhatridge_train)
mae_train = mae(y_train,  yhatridge_train)
mape_train = mape(y_train,  yhatridge_train)

# %%
d = 4
a = 166
max_it = 215

yhatridge_val = ridge_polynomial_regression(d, x_train, y_train, x_val, a, max_it)
r2_val = r2_score(y_val,  yhatridge_val)
mse_val = mse(y_val,  yhatridge_val)
rmse_val = rmse(y_val,  yhatridge_val)
mae_val = mae(y_val,  yhatridge_val)
mape_val = mape(y_val,  yhatridge_val)

# %%
d = 4
a = 166
max_it = 215

yhatridge_test = ridge_polynomial_regression(d, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test, a, max_it)
r2_test = r2_score(y_test,  yhatridge_test)
mse_test = mse(y_test,  yhatridge_test)
rmse_test = rmse(y_test,  yhatridge_test)
mae_test = mae(y_test,  yhatridge_test)
mape_test = mape(y_test,  yhatridge_test)

# %%
# desenhar tabela

# %% [markdown]
# #### c) Elastic Net

# %%
def elastic_polynomial_regression(d, x_train, y_train, x_test, a, ratio, max_it):
    poly = pp.PolynomialFeatures(degree=d)
    xtrain_poly = poly.fit_transform(x_train)
    xtest_poly = poly.fit_transform(x_test)
    elastic_net = lm.ElasticNet(alpha=a, l1_ratio=ratio, max_iter=max_it, random_state=42)
    elastic_net.fit(xtrain_poly, y_train)
    yhat_elastic = elastic_net.predict(xtest_poly)
    return yhat_elastic

# %% [markdown]
# ##### dados treino

# %%
d = np.arange(1, 5, 1)
a = np.arange(1, 171, 15)
max_it = np.arange(5, 221, 35)
ratio = [0.1, 0.5, 0.9]
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
rmse_min = 100000
best_d = None
best_a = None
best_max_it = None

for i in range(len(d)):
    for j in range(len(a)):
        for l in range(len(ratio)):
            for k in range(len(max_it)):
                yhatelastic_train = elastic_polynomial_regression(d[i], x_train, y_train, x_train, a[j], ratio[l], max_it[k])
                r2_train = r2_score(y_train,  yhatelastic_train)
                mse_train = mse(y_train,  yhatelastic_train)
                rmse_train = rmse(y_train,  yhatelastic_train)
                mae_train = mae(y_train,  yhatelastic_train)
                mape_train = mape(y_train,  yhatelastic_train)
                r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_train,
                                                                                 mse_list, mse_train,
                                                                                 rmse_list, rmse_train,
                                                                                 mae_list, mae_train,
                                                                                 mape_list, mape_train)
                if rmse_train < rmse_min:
                    rmse_min = rmse_train
                    best_d_train = d[i]
                    best_a_train = a[j]
                    best_rat_train = ratio[l]
                    best_max_it_train = max_it[k]

print("Melhor degree:{}".format(best_d_train))
print()
print("Melhor alpha:{}".format(best_a_train))
print()
print("Melhor l1_ratio:{}".format(best_rat_train))
print()
print("Melhor max_iter:{}".format(best_max_it_train))
# Out:
# Melhor degree:4
#
# Melhor alpha:166
#
# Melhor l1_ratio:0.9
#
# Melhor max_iter:215

# %% [markdown]
# ##### dados treino e validação

# %%
d = np.arange(1, 5, 1)
a = np.arange(1, 171, 15)
max_it = np.arange(5, 221, 35)
ratio = [0.1, 0.5, 0.9]
coef =[]
intercepts =[]
preds =[]
r2_list=[]
mse_list=[]
rmse_list=[]
mae_list=[]
mape_list=[]
rmse_min = 100000
best_d = None
best_a = None
best_max_it = None

for i in range(len(d)):
    for j in range(len(a)):
        for l in range(len(ratio)):
            for k in range(len(max_it)):
                yhatelastic_val = elastic_polynomial_regression(d[i], x_train, y_train, x_val, a[j], ratio[l], max_it[k])
                r2_val = r2_score(y_val,  yhatelastic_val)
                mse_val = mse(y_val,  yhatelastic_val)
                rmse_val = rmse(y_val,  yhatelastic_val)
                mae_val = mae(y_val,  yhatelastic_val)
                mape_val = mape(y_val,  yhatelastic_val)
                r2_list, mse_list, rmse_list, mae_list, mape_list = metrics_list(r2_list, r2_val,
                                                                                 mse_list, mse_val,
                                                                                 rmse_list, rmse_val,
                                                                                 mae_list, mae_val,
                                                                                 mape_list, mape_val)
                if rmse_train < rmse_min:
                    rmse_min = rmse_val
                    best_d_val = d[i]
                    best_a_val = a[j]
                    best_rat_val = ratio[l]
                    best_max_it_val = max_it[k]

print("Melhor degree:{}".format(best_d_val))
print()
print("Melhor alpha:{}".format(best_a_val))
print()
print("Melhor l1_ratio:{}".format(best_rat_val))
print()
print("Melhor max_iter:{}".format(best_max_it_val))
# Out:
# Melhor degree:1
#
# Melhor alpha:1
#
# Melhor l1_ratio:0.1
#
# Melhor max_iter:5

# %% [markdown]
# ##### dados treino, validação e teste

# %%
d = 1
a = 1
max_it = 5
ratio = 0.1

yhatelastic_train = elastic_polynomial_regression(d, x_train, y_train, x_train, a, ratio, max_it)
r2_train = r2_score(y_train,  yhatelastic_train)
mse_train = mse(y_train,  yhatelastic_train)
rmse_train = rmse(y_train,  yhatelastic_train)
mae_train = mae(y_train,  yhatelastic_train)
mape_train = mape(y_train,  yhatelastic_train)

# %%
d = 1
a = 1
max_it = 5
ratio = 0.1

yhatelastic_val = elastic_polynomial_regression(d, x_train, y_train, x_val, a, ratio, max_it)
r2_val = r2_score(y_val,  yhatelastic_val)
mse_val = mse(y_val,  yhatelastic_val)
rmse_val = rmse(y_val,  yhatelastic_val)
mae_val = mae(y_val,  yhatelastic_val)
mape_val = mape(y_val,  yhatelastic_val)

# %%
d = 1
a = 1
max_it = 5
ratio = 0.1

yhatelastic_test = elastic_polynomial_regression(d, pd.concat([x_train, x_val]), pd.concat([y_train, y_val]), x_test, a, ratio, max_it)
r2_test = r2_score(y_test,  yhatelastic_test)
mse_test = mse(y_test,  yhatelastic_test)
rmse_test = rmse(y_test,  yhatelastic_test)
mae_test = mae(y_test,  yhatelastic_test)
mape_test = mape(y_test,  yhatelastic_test)
